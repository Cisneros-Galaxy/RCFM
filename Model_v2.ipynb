# %% [markdown]
# # RCFM Model

# %% [markdown]
# ## 1. Import modules and helper functions

# %%
# Modules
import matplotlib.pyplot as plt
import numpy as np
from math import sqrt
from scipy.optimize import curve_fit

# Helper functions from DataAid.py and DataImport.py
import DataAid
import DataImporter

# Numerically stable class of functions from Neros_v2.py
import Neros_v2

# %% [markdown]
# ## 2. Load Galaxy Data

# %%
# Load Galaxy Data
sparcGalaxies = DataAid.GetGalaxyData("data/Sparc/Rotmod_LTG/")
littleDataGalaxies = DataAid.GetGalaxyData("data/little-data-things/data/")
lcmGalaxies = DataAid.GetGalaxyData("data/LCMFits/data/")

# Load Milky Way Model Data
xueSofueGalaxies = DataAid.GetGalaxyData("data/XueSofue/")
mcGaughMW = DataAid.GetGalaxyData("data/McGaugh/")

# Create array of Milky Way radius and vlum tuples from model data
MWXueSofue = np.array(xueSofueGalaxies['MW_lum'])
MWMcGaugh = np.array(mcGaughMW['MW_lumMcGaugh'])

# %% [markdown]
# ## 3. Create Neros class instance

# %%
# Create Neros instance to perform calculations with the supplied Milky Way model as comparison
# Change Milky Way model by changing the variable in the parentheses
# i.e. neros_fns = Neros_v2.Neros(MWModelVariable)

neros_fns = Neros_v2.Neros(MWXueSofue)
MW_name = "MWXueSofue" # Change this if you change the MW model in neros_fns!
MW_rad = neros_fns.mwRad
MW_vLum = neros_fns.mwVLum

MW_vLum_interp_func = neros_fns.mw_vLum_interp

# %% [markdown]
# ## 4. Designate outfile name, initialize variables, and designate galaxy sample

# %%
# This is where the fitted alpha & vlum free parameter will be written for each galaxy
out_file = "imported-data/data_" + str(MW_name) + ".csv"
with open(out_file, 'w') as f:
    f.write('{0},{1},{2},{3}\n'.format("Galaxy", "Chisquare",  "Alpha", "Beta"))
f.close()

vLcmList = []

avgChiSquared = 0.0
avgPhiZero = 0.0

# This designates which galaxy sample to fit
galaxies = sparcGalaxies

# %% [markdown]
# ## 5. Fit galaxies, print and save graphs

# %%
"""
This is the main body of the model. 
It loops through galaxies in the designated sample,
it calculates vLCM, vNeros, and chiSquared,
it fits galaxy data using alpha and vLumFreeParam,
it prints the values of alpha and vLumFreeParam to the console,
and it saves the graphs to a file.
"""
for galaxyName in galaxies:
    f, ax = plt.subplots(1, figsize = (15, 15))
    galaxy = np.array(galaxies[galaxyName])
    galaxy_rad = galaxy[:,0]
    galaxy_vObs = galaxy[:,1]
    galaxy_error = galaxy[:,2]
    galaxy_gas = galaxy[:,3]
    galaxy_disk = galaxy[:,4]
    galaxy_bulge = galaxy[:,5]

    # calculate vlumsquared
    galaxy_vLumSquared = neros_fns.vLumSquared(galaxy_gas, galaxy_disk, galaxy_bulge)
    galaxy_vLum = np.sqrt(galaxy_vLumSquared)
    
    # Make sure the arrays are matching lengths
    maxMWRad = MW_rad[len(MW_rad)-1]
    for i in range(len(galaxy_rad)):
        if galaxy_rad[i] > maxMWRad:
            galaxy_rad = galaxy_rad[:i]
            galaxy_vLum = galaxy_vLum[:i]
            galaxy_vObs = galaxy_vObs[:i]
            galaxy_gas = galaxy_gas[:i]
            galaxy_disk = galaxy_disk[:i]
            galaxy_bulge = galaxy_bulge[:i]
            galaxy_error = galaxy_error[:i]
            break
            
    # Find fittedAlpha and fittedVLumFreeParam from curve_fit function
    vals, cov = curve_fit(neros_fns.curve_fit_fn,(galaxy_rad, galaxy_gas, galaxy_disk, galaxy_bulge),
                          galaxy_vObs,sigma=galaxy_error)
    fittedAlpha, fittedVLumFreeParam, disk_scale, bulge_scale = vals

    # Calculate vLCM and vNeros
    vLcm = neros_fns.vLCM(galaxy_rad, galaxy_vLum)
    vLcmList.append(vLcm)
    vNeros = neros_fns.curve_fit_fn((galaxy_rad, galaxy_gas, galaxy_disk, galaxy_bulge),
                                    fittedAlpha, fittedVLumFreeParam, disk_scale, bulge_scale)

    # Calculate chi squared
    chiSquare = neros_fns.chiSquared(galaxy_vObs, vNeros, galaxy_error)
    avgChiSquared = avgChiSquared + chiSquare

    # printing to file & console
    print(f"galaxyName is: {galaxyName}")

    print(f"chiSquare is: {chiSquare}")

    print(f"fittedAlpha is: {fittedAlpha}, \nfittedVLumFreeParam is: {fittedVLumFreeParam}")
    
    print(f"disk_scale is: {disk_scale}, \nbulge_scale is: {bulge_scale}")
    
    print(f"avgChiSquared / len(lcmGalaxies) is: {avgChiSquared / len(lcmGalaxies)}")

    print("--------------------------")

    # Write galaxyName, fittedAlpha, fittedVLumFreeParam to file
    with open(out_file, 'a') as f:
        f.write('{0},{1},{2},{3}\n'.format(galaxyName, chiSquare, fittedAlpha, fittedVLumFreeParam))
    f.close()

    # Calculate galaxy_vObs plus error and put into list
    galaxy_vObs_err_incl = []
    for i in range(len(galaxy_vObs)):
        galaxy_vObs_err_incl.append(galaxy_vObs[i] + galaxy_error[i])

    # calculate new vLum
    galaxy_vLum_updated = []
    for i in range(len(galaxy_vLum)):
        galaxy_vLum_updated.append(galaxy_vLum[i] * fittedVLumFreeParam)

    # plot
    # y-axis scales to the maximum velocity value in the list galaxy_vObs_err_incl
    # or to the maximum value in the list vNeros, whichever is the bigger number
    y_max = max(max(galaxy_vObs_err_incl), max(vNeros))
    ax.set_ylim(bottom = 0, top = y_max + 15)

    # plot vObs and vNeros and updated vLum
    ax.plot(galaxy_rad, vNeros, label="{}_vNeros".format(galaxyName))
    ax.plot(galaxy_rad, galaxy_vObs, label="{}_vObs".format(galaxyName))
    ax.plot(galaxy_rad, galaxy_vLum_updated, label="{}_new_vLum".format(galaxyName))

    # error bar in vObs
    for i in range(len(galaxy_rad)):
        ax.vlines(galaxy_rad[i], galaxy_vObs[i] - galaxy_error[i], galaxy_vObs[i] + galaxy_error[i])

    ax.legend(loc="upper right")

    graph_file_name = "graphs/" + str(galaxyName) + "_" + str(MW_name)

    plt.savefig(graph_file_name)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# galaxyName is: NGC5371_rotmod
# chiSquare is: 7.4798559664085795
# fittedAlpha is: 77.27531542421838,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.6018771859222677,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 0.5342754261720414
# --------------------------
# galaxyName is: UGC07603_rotmod
# chiSquare is: 1.161209895721733
# fittedAlpha is: 3200.8503545311855,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.3897592666859078,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 0.6172189901521652
# --------------------------
# galaxyName is: NGC4138_rotmod
# chiSquare is: 0.11522999238208267
# fittedAlpha is: 97.13080664941955,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.6960261377187111,
# bulge_scale is: -2.4896821617267193
# avgChiSquared / len(lcmGalaxies) is: 0.6254497038937427
# --------------------------
# galaxyName is: UGC12632_rotmod
# chiSquare is: 0.1652902351798359
# fittedAlpha is: 894.9660553449064,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.4524471793057416,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 0.6372561492637309
# --------------------------
# /Users/meagancrowley/RCFM/Neros_v2.py:86: RuntimeWarning: invalid value encountered in sqrt
#   vLum_scaled = np.sqrt(self.vLumSquared(vGas,vDisk,vBulge,disk_scale,bulge_scale))
# galaxyName is: NGC5033_rotmod
# chiSquare is: 12.505545419687975
# fittedAlpha is: 99.40580094952023,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.1017052892909391,
# bulge_scale is: 0.17416581225230515
# avgChiSquared / len(lcmGalaxies) is: 1.5305093935271576
# --------------------------
# galaxyName is: UGC02023_rotmod
# chiSquare is: 0.026884398152078937
# fittedAlpha is: 23438.510754991843,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.4703740195434041,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 1.5324297076808775
# --------------------------
# galaxyName is: UGC09133_rotmod
# chiSquare is: 6.924834725765443
# fittedAlpha is: 161.72093520583448,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.7741278289901559,
# bulge_scale is: 0.4482941699418997
# avgChiSquared / len(lcmGalaxies) is: 2.0270607595212664
# --------------------------
# galaxyName is: UGCA442_rotmod
# chiSquare is: 1.4346400512518458
# fittedAlpha is: 3017.9173795646234,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 6.09643478410685,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 2.129535048896398
# --------------------------
# galaxyName is: UGC04305_rotmod
# chiSquare is: 1.1136649839843658
# fittedAlpha is: -1032.5506014299767,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.9921355934423791,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 2.2090825477524243
# --------------------------
# galaxyName is: NGC2841_rotmod
# chiSquare is: 1.069454493368364
# fittedAlpha is: 236.68822916076593,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.1231991581698302,
# bulge_scale is: 0.9837118787534757
# avgChiSquared / len(lcmGalaxies) is: 2.2854721544215932
# --------------------------
# galaxyName is: NGC2955_rotmod
# chiSquare is: 3.589240054899879
# fittedAlpha is: 227.14673819560647,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.16104376839751838,
# bulge_scale is: 0.8031297534171549
# avgChiSquared / len(lcmGalaxies) is: 2.541846444057299
# --------------------------
# galaxyName is: UGC07232_rotmod
# chiSquare is: 0.13497512926182664
# fittedAlpha is: 22623.329684082695,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.6750276655975316,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 2.551487524718858
# --------------------------
# galaxyName is: NGC4157_rotmod
# chiSquare is: 0.16470619631851294
# fittedAlpha is: 220.927597309947,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5483054917247929,
# bulge_scale is: -0.03794023202846908
# avgChiSquared / len(lcmGalaxies) is: 2.563252253027323
# --------------------------
# galaxyName is: NGC4183_rotmod
# chiSquare is: 0.23167615694861865
# fittedAlpha is: 332.78127155961295,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.6178598359127432,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 2.5798005499522243
# --------------------------
# galaxyName is: UGC07125_rotmod
# chiSquare is: 0.8464488972855444
# fittedAlpha is: 1276.372035822701,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.15322214656901,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 2.6402611854726206
# --------------------------
# galaxyName is: UGC03205_rotmod
# chiSquare is: 2.537738614058985
# fittedAlpha is: 120.96609879552004,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.743535098750761,
# bulge_scale is: 1.0764257515446998
# avgChiSquared / len(lcmGalaxies) is: 2.821528229333977
# --------------------------
# galaxyName is: F583-1_rotmod
# chiSquare is: 1.070262360968206
# fittedAlpha is: 3303.306297089731,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.317753749040185,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 2.897975540831706
# --------------------------
# galaxyName is: NGC4068_rotmod
# chiSquare is: 0.09593154181544444
# fittedAlpha is: 26143.455952680124,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5337664461359524,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 2.9048277938185234
# --------------------------
# galaxyName is: UGC02885_rotmod
# chiSquare is: 0.9693201894136732
# fittedAlpha is: 233.0456421529956,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.06521536374172603,
# bulge_scale is: 1.098148699106498
# avgChiSquared / len(lcmGalaxies) is: 2.9740649502052143
# --------------------------
# galaxyName is: D564-8_rotmod
# chiSquare is: 0.14161359900069456
# fittedAlpha is: 24250.28566983719,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.6120664641839388,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 2.9841802072766925
# --------------------------
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   # Remove the CWD from sys.path while we load stuff.
# galaxyName is: NGC4013_rotmod
# chiSquare is: 0.7049696096474483
# fittedAlpha is: 271.0020923168009,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5241645374388141,
# bulge_scale is: 1.41927209114209
# avgChiSquared / len(lcmGalaxies) is: 3.0345351793943673
# --------------------------
# galaxyName is: UGC07323_rotmod
# chiSquare is: 0.2072081339482182
# fittedAlpha is: 3322.6561435096382,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.8666999597609262,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 3.049335760390669
# --------------------------
# galaxyName is: NGC3953_rotmod
# chiSquare is: 0.44299305446281756
# fittedAlpha is: 60.21907397326294,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.8105265185857194,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 3.080978121423727
# --------------------------
# galaxyName is: NGC4559_rotmod
# chiSquare is: 0.40815757812848463
# fittedAlpha is: 543.7314030209263,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.6597150853071256,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 3.11013223414719
# --------------------------
# galaxyName is: NGC6015_rotmod
# chiSquare is: 8.564801648746304
# fittedAlpha is: 211.26332145374468,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.0287094960608865,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 3.721903780486212
# --------------------------
# galaxyName is: UGC05253_rotmod
# chiSquare is: 7.295067524890177
# fittedAlpha is: 139.626337063856,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.6681600157990593,
# bulge_scale is: 0.5627315441548663
# avgChiSquared / len(lcmGalaxies) is: 4.242980032264081
# --------------------------
# galaxyName is: UGC12506_rotmod
# chiSquare is: 1.018754544288996
# fittedAlpha is: 152.19239714235937,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.8193508932811482,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 4.31574821399901
# --------------------------
# galaxyName is: NGC2998_rotmod
# chiSquare is: 2.7057602405734147
# fittedAlpha is: 157.93143460349842,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.8423269661737111,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 4.509016802611397
# --------------------------
# galaxyName is: UGC00731_rotmod
# chiSquare is: 0.04840753131572418
# fittedAlpha is: 782.9662204982042,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 14.231782771910364,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 4.512474483419663
# --------------------------
# galaxyName is: F583-4_rotmod
# chiSquare is: 0.18959319984112144
# fittedAlpha is: 1515.882669970862,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.6766264810782152,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 4.526016854836885
# --------------------------
# galaxyName is: UGC06614_rotmod
# chiSquare is: 0.04568068994171065
# fittedAlpha is: 231.20449938729251,
# fittedVLumFreeParam is: 1.0
# disk_scale is: -0.21414900435356307,
# bulge_scale is: 0.5686581778557743
# avgChiSquared / len(lcmGalaxies) is: 4.529279761261294
# --------------------------
# galaxyName is: NGC0024_rotmod
# chiSquare is: 0.33227556285189996
# fittedAlpha is: 297.2525784193146,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.0145967944543886,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 4.553013730036429
# --------------------------
# galaxyName is: DDO168_rotmod
# chiSquare is: 3.668662942935825
# fittedAlpha is: 17580.868474391766,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5719001005662958,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 4.815061083103274
# --------------------------
# galaxyName is: UGC05750_rotmod
# chiSquare is: 0.3366984371118228
# fittedAlpha is: 1025.63688226386,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.4506006641857447,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 4.839110971468403
# --------------------------
# galaxyName is: UGC05005_rotmod
# chiSquare is: 0.10006292201181317
# fittedAlpha is: 3283.4019198721217,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.112794168392149,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 4.846258323040677
# --------------------------
# galaxyName is: M31_Carignan_SNC
# chiSquare is: 0.3062163669305487
# fittedAlpha is: 100.97189813759992,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.0113066114661915,
# bulge_scale is: 0.9289497591151794
# avgChiSquared / len(lcmGalaxies) is: 4.868130920678572
# --------------------------
# galaxyName is: NGC3893_rotmod
# chiSquare is: 1.2803762759581454
# fittedAlpha is: 253.4083657920664,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5992760737384919,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 4.959586368961297
# --------------------------
# galaxyName is: UGC12732_rotmod
# chiSquare is: 0.19931861053083116
# fittedAlpha is: 1835.8098999307974,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.395096690011236,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 4.973823412570643
# --------------------------
# galaxyName is: UGC06818_rotmod
# chiSquare is: 0.8176848595778057
# fittedAlpha is: 39453.756952933465,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.24832253585018624,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 5.032229473969058
# --------------------------
# galaxyName is: IC4202_rotmod
# chiSquare is: 26.833644021878712
# fittedAlpha is: 262.24829594598486,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.9666307442952007,
# bulge_scale is: 0.5230503601908026
# avgChiSquared / len(lcmGalaxies) is: 6.94891833267468
# --------------------------
# galaxyName is: UGC00128_rotmod
# chiSquare is: 6.821480028240412
# fittedAlpha is: 406.77195229198696,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.13153223268929,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 7.436166906120424
# --------------------------
# galaxyName is: D631-7_rotmod
# chiSquare is: 0.4154068066019315
# fittedAlpha is: 19992.326106276807,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.24879019462060592,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 7.465838820877705
# --------------------------
# /Users/meagancrowley/RCFM/Neros_v2.py:111: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(self.vNerosSquared(galaxy_rad, galaxy_vLum, alpha, phi_zero=3e-11))
# galaxyName is: F568-V1_rotmod
# chiSquare is: 0.10584364292927705
# fittedAlpha is: 364.31564743660675,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 4.690907856552526,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 7.473399081086939
# --------------------------
# galaxyName is: UGC06667_rotmod
# chiSquare is: 0.3208992245618011
# fittedAlpha is: -1118.8089095533426,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 18.928729472835148,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 7.496320454269925
# --------------------------
# galaxyName is: UGC05918_rotmod
# chiSquare is: 0.1261792848147202
# fittedAlpha is: 320.9140523195194,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 5.273982781643678,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 7.505333260328119
# --------------------------
# galaxyName is: UGC00634_rotmod
# chiSquare is: 4.799293184319957
# fittedAlpha is: 1548.5470640184517,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.9378466768004445,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 7.8481399163509735
# --------------------------
# galaxyName is: UGC02487_rotmod
# chiSquare is: 4.227963610681012
# fittedAlpha is: 390.5632480739636,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.5180500333375824,
# bulge_scale is: 0.4762576626630878
# avgChiSquared / len(lcmGalaxies) is: 8.150137317113904
# --------------------------
# galaxyName is: UGC05999_rotmod
# chiSquare is: 1.2530732830812226
# fittedAlpha is: 3993.7913074644744,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.4960250041019938,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 8.239642551619704
# --------------------------
# galaxyName is: F568-1_rotmod
# chiSquare is: 0.44062717097441273
# fittedAlpha is: 1785.0394345649415,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.241519506834831,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 8.271115920975019
# --------------------------
# galaxyName is: NGC2976_rotmod
# chiSquare is: 0.37179170910881
# fittedAlpha is: 2134.9856627823656,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.7794818070209338,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 8.29767247162565
# --------------------------
# galaxyName is: NGC3917_rotmod
# chiSquare is: 2.0523704937771425
# fittedAlpha is: 414.2557535873957,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.2863826103115585,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 8.444270364038301
# --------------------------
# galaxyName is: F571-V1_rotmod
# chiSquare is: 0.2052273610057543
# fittedAlpha is: 2064.110370880851,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.42227702379345,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 8.458929461252998
# --------------------------
# galaxyName is: NGC3972_rotmod
# chiSquare is: 1.1192513317231483
# fittedAlpha is: 1028.648382598205,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.0204896821782725,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 8.53887598494751
# --------------------------
# galaxyName is: NGC0801_rotmod
# chiSquare is: 4.3481331577831845
# fittedAlpha is: 106.92568489972615,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5984107058150568,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 8.849456924789164
# --------------------------
# galaxyName is: NGC6946_rotmod
# chiSquare is: 2.4120735262650617
# fittedAlpha is: 131.4766332372571,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5230624164666645,
# bulge_scale is: 0.32559897113017366
# avgChiSquared / len(lcmGalaxies) is: 9.021747890950955
# --------------------------
# galaxyName is: F563-V2_rotmod
# chiSquare is: 0.08919763625722871
# fittedAlpha is: 551.0845807214115,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 4.848669452920202,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 9.028119150683613
# --------------------------
# galaxyName is: UGC02953_rotmod
# chiSquare is: 128.89114692087946
# fittedAlpha is: -1070.6981705159553,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.826178673933552,
# bulge_scale is: -0.02486477890700356
# avgChiSquared / len(lcmGalaxies) is: 18.234629645032147
# --------------------------
# galaxyName is: F567-2_rotmod
# chiSquare is: 0.19482131197266087
# fittedAlpha is: 713.7124454671095,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.6843896309299378,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 18.248545453030196
# --------------------------
# galaxyName is: NGC7331_rotmod
# chiSquare is: 0.4223496857047205
# fittedAlpha is: 203.6129642753947,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.46516617217563777,
# bulge_scale is: -0.3041463514341343
# avgChiSquared / len(lcmGalaxies) is: 18.278713287723388
# --------------------------
# galaxyName is: NGC5907_rotmod
# chiSquare is: 4.8575568329606895
# fittedAlpha is: 185.83078568230977,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.9341400759175473,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 18.625681632934867
# --------------------------
# galaxyName is: NGC3726_rotmod
# chiSquare is: 1.3760791521825162
# fittedAlpha is: 374.92228197850903,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.6145217554555387,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 18.723973000947904
# --------------------------
# galaxyName is: NGC3198_rotmod
# chiSquare is: 5.6554922922401145
# fittedAlpha is: 259.9903432717454,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.8872870741258241,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 19.127936736107916
# --------------------------
# galaxyName is: NGC0891_rotmod
# chiSquare is: 4.9480583522568855
# fittedAlpha is: 166.13756582542064,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.29735579564911757,
# bulge_scale is: 0.5850676504258245
# avgChiSquared / len(lcmGalaxies) is: 19.481369475554835
# --------------------------
# galaxyName is: NGC0100_rotmod
# chiSquare is: 0.25026478373633526
# fittedAlpha is: 2953.2027161350097,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.9462316183849546,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 19.499245531536
# --------------------------
# galaxyName is: NGC4217_rotmod
# chiSquare is: 1.285888371441515
# fittedAlpha is: 288.4375130968148,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.877030657457174,
# bulge_scale is: 0.18902191161504903
# avgChiSquared / len(lcmGalaxies) is: 19.591094700924682
# --------------------------
# galaxyName is: UGC09992_rotmod
# chiSquare is: 0.01732783014257005
# fittedAlpha is: 10.340945418358812,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.6772059969856872,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 19.592332403077723
# --------------------------
# galaxyName is: UGC06786_rotmod
# chiSquare is: 3.087170563171714
# fittedAlpha is: 175.30545186114625,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.8563060507321708,
# bulge_scale is: 0.5977008405319226
# avgChiSquared / len(lcmGalaxies) is: 19.812844586161415
# --------------------------
# galaxyName is: D512-2_rotmod
# chiSquare is: 0.05290706944748419
# fittedAlpha is: 2048.558776067345,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.203023347673101,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 19.81662366255052
# --------------------------
# galaxyName is: UGC06917_rotmod
# chiSquare is: 0.822768766314876
# fittedAlpha is: 1433.6525709767548,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.2533967327221642,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 19.87539286014444
# --------------------------
# galaxyName is: ESO563-G021_rotmod
# chiSquare is: 15.275202387891778
# fittedAlpha is: 373.14683625603186,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.9403287293882214,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 20.966478744993854
# --------------------------
# galaxyName is: NGC4100_rotmod
# chiSquare is: 2.00065577805546
# fittedAlpha is: 201.1135747985695,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.956349780961458,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 21.109382729140673
# --------------------------
# galaxyName is: NGC3877_rotmod
# chiSquare is: 6.867463632327813
# fittedAlpha is: 138.05571760020345,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.6949786733357456,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 21.59991584573552
# --------------------------
# galaxyName is: UGC00191_rotmod
# chiSquare is: 1.5285242690968857
# fittedAlpha is: 924.3151644449729,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.961326084818852,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 21.70909615067101
# --------------------------
# galaxyName is: NGC3741_rotmod
# chiSquare is: 0.952310522772791
# fittedAlpha is: 50536.521224787924,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.46679454085545713,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 21.777118330869065
# --------------------------
# galaxyName is: NGC0247_rotmod
# chiSquare is: 1.922005111015155
# fittedAlpha is: 353.53310957057846,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.3041435967317705,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 21.91440441022729
# --------------------------
# galaxyName is: F563-1_rotmod
# chiSquare is: 0.8647193879066828
# fittedAlpha is: 1540.5581024918706,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 4.430248210464621,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 21.976170080792055
# --------------------------
# galaxyName is: F574-2_rotmod
# chiSquare is: 0.04838357293395402
# fittedAlpha is: 3886.2012031123613,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.3946467627525267,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 21.97962605028734
# --------------------------
# galaxyName is: UGC06399_rotmod
# chiSquare is: 0.17637412385535783
# fittedAlpha is: 1633.9286287539849,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.043870581792409,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 21.99222420199129
# --------------------------
# galaxyName is: UGC11820_rotmod
# chiSquare is: 1.6316497700363546
# fittedAlpha is: 2635.7452495322564,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.6162413795463426,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 22.108770614136745
# --------------------------
# galaxyName is: F568-3_rotmod
# chiSquare is: 1.4873069316289524
# fittedAlpha is: 2681.716029718272,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.6164361322798169,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 22.21500682353881
# --------------------------
# galaxyName is: UGC07524_rotmod
# chiSquare is: 1.1461158691675974
# fittedAlpha is: 1605.5583535190012,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.192939094867446,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 22.29687224276507
# --------------------------
# galaxyName is: UGC02259_rotmod
# chiSquare is: 2.317410319941004
# fittedAlpha is: 555.6112540351954,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.343120251540615,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 22.462401551332285
# --------------------------
# galaxyName is: UGC05721_rotmod
# chiSquare is: 1.8581299924160422
# fittedAlpha is: 830.7170242062084,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.6585719696290757,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 22.595125122219144
# --------------------------
# galaxyName is: UGC05716_rotmod
# chiSquare is: 4.342429229397415
# fittedAlpha is: 2060.5554341854613,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.717916829129683,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 22.905298638604673
# --------------------------
# galaxyName is: UGC07151_rotmod
# chiSquare is: 0.9768555874382098
# fittedAlpha is: 950.4631937518686,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.328200221954276,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 22.9750740377074
# --------------------------
# galaxyName is: UGC04483_rotmod
# chiSquare is: 0.39607226773971904
# fittedAlpha is: 8614.089704801925,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.7331349738617996,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 23.003364913974526
# --------------------------
# galaxyName is: NGC1003_rotmod
# chiSquare is: 2.2553189668842233
# fittedAlpha is: 715.6616290820721,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.9598968516399323,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 23.164459125894826
# --------------------------
# galaxyName is: UGC03546_rotmod
# chiSquare is: 1.5934971197539138
# fittedAlpha is: 93.778596641993,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.7057302277721278,
# bulge_scale is: 0.3202901560683033
# avgChiSquared / len(lcmGalaxies) is: 23.27828034873439
# --------------------------
# galaxyName is: NGC0055_rotmod
# chiSquare is: 2.6476686741802236
# fittedAlpha is: 2892.2349515668457,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.006559812375068,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 23.467399539747266
# --------------------------
# galaxyName is: NGC1090_rotmod
# chiSquare is: 2.5868708293678875
# fittedAlpha is: 207.40654718905878,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.7401375460542673,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 23.652176027559257
# --------------------------
# galaxyName is: UGC06973_rotmod
# chiSquare is: 0.06916624503739294
# fittedAlpha is: 449.63533704335777,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.7986380453750811,
# bulge_scale is: -3.307826134531101
# avgChiSquared / len(lcmGalaxies) is: 23.657116473633355
# --------------------------
# galaxyName is: F574-1_rotmod
# chiSquare is: 1.0365791943492169
# fittedAlpha is: 864.548152723092,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.271457631130028,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 23.7311578446583
# --------------------------
# galaxyName is: NGC3769_rotmod
# chiSquare is: 2.1990894170908777
# fittedAlpha is: 286.90965182845684,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.6749383603128805,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 23.88823566016479
# --------------------------
# galaxyName is: NGC2403_rotmod
# chiSquare is: 18.423593800599303
# fittedAlpha is: 497.3722815782686,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.8865669694499719,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 25.204206645921882
# --------------------------
# galaxyName is: UGC03580_rotmod
# chiSquare is: 2.3491419316098354
# fittedAlpha is: 741.7256529428093,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.6003612314397301,
# bulge_scale is: 0.12201454749337919
# avgChiSquared / len(lcmGalaxies) is: 25.37200249817973
# --------------------------
# galaxyName is: ESO444-G084_rotmod
# chiSquare is: 0.49977949023170004
# fittedAlpha is: 4148.539941049017,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 4.673897233179155,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 25.407701033196275
# --------------------------
# galaxyName is: NGC6789_rotmod
# chiSquare is: 0.13514877921658497
# fittedAlpha is: 19333.504370979703,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.890530226329816,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 25.41735451742603
# --------------------------
# galaxyName is: UGC11557_rotmod
# chiSquare is: 0.7055006547585684
# fittedAlpha is: 2232.7145075701824,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.35395342412966735,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 25.467747421337357
# --------------------------
# galaxyName is: UGC08490_rotmod
# chiSquare is: 0.9134121463430455
# fittedAlpha is: 513.5527260489706,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.0244106658975203,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 25.532991146076146
# --------------------------
# galaxyName is: UGC01230_rotmod
# chiSquare is: 0.6398800252849964
# fittedAlpha is: 236.29475448165073,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.084166540385616,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 25.57869686216793
# --------------------------
# galaxyName is: UGC08550_rotmod
# chiSquare is: 0.14952346929245122
# fittedAlpha is: 2083.232992768161,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.0763030950096706,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 25.58937710997453
# --------------------------
# galaxyName is: F561-1_rotmod
# chiSquare is: 0.31136007035393237
# fittedAlpha is: -1205.759210686617,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.2726740248131174,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 25.611617114999813
# --------------------------
# galaxyName is: UGC07559_rotmod
# chiSquare is: 0.0979333914215103
# fittedAlpha is: 14020.282818203146,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.8737101031725302,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 25.61861235724421
# --------------------------
# galaxyName is: NGC4389_rotmod
# chiSquare is: 0.03557522122246489
# fittedAlpha is: 17797.406929508965,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.07966723231189746,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 25.621153444474384
# --------------------------
# galaxyName is: NGC2915_rotmod
# chiSquare is: 0.6124247834879991
# fittedAlpha is: 13834.05143278922,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.2290011803882846,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 25.664898071866386
# --------------------------
# galaxyName is: NGC5055_rotmod
# chiSquare is: 51.80614946880598
# fittedAlpha is: 98.23582200343367,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.4676044372921568,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 29.36533731963824
# --------------------------
# galaxyName is: UGC07399_rotmod
# chiSquare is: 1.216138248429314
# fittedAlpha is: 1703.00839423166,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.583068858436809,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 29.452204337383193
# --------------------------
# galaxyName is: F565-V2_rotmod
# chiSquare is: 0.14925955740657645
# fittedAlpha is: 5794.99845351532,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 4.637490548792238,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 29.462865734340806
# --------------------------
# galaxyName is: NGC3992_rotmod
# chiSquare is: 0.8014290889440981
# fittedAlpha is: 208.90022628094178,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.1160666793856613,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 29.520110669265385
# --------------------------
# galaxyName is: NGC6503_rotmod
# chiSquare is: 9.8545825579277
# fittedAlpha is: 259.9667651251993,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.7670022592951204,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 30.22400942340308
# --------------------------
# galaxyName is: PGC51017_rotmod
# chiSquare is: 1.1069400297728758
# fittedAlpha is: -355.83084532708233,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.6970713742479948,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 30.303076568386853
# --------------------------
# galaxyName is: NGC1705_rotmod
# chiSquare is: 0.25966580310932247
# fittedAlpha is: 342.89696743786965,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.249163449978698,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 30.321624125751807
# --------------------------
# galaxyName is: ESO079-G014_rotmod
# chiSquare is: 2.9727492509006974
# fittedAlpha is: 659.43618010473,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.152510903084024,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 30.533963357959
# --------------------------
# galaxyName is: F563-V1_rotmod
# chiSquare is: 0.017046931052534204
# fittedAlpha is: -2292.9866145434626,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.2923395952171128,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 30.535180995891324
# --------------------------
# galaxyName is: NGC6195_rotmod
# chiSquare is: 1.893227301963281
# fittedAlpha is: 197.7195850476523,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.14982910167430027,
# bulge_scale is: 0.6999869690688993
# avgChiSquared / len(lcmGalaxies) is: 30.67041151746013
# --------------------------
# galaxyName is: DDO161_rotmod
# chiSquare is: 1.83674829958219
# fittedAlpha is: 3336.999290451752,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.2290617554510168,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 30.801607824573146
# --------------------------
# galaxyName is: UGC07577_rotmod
# chiSquare is: 0.03525825941218531
# fittedAlpha is: 36409.24333344903,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.43034528856104093,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 30.804126271674015
# --------------------------
# galaxyName is: UGC04499_rotmod
# chiSquare is: 1.0771189541847055
# fittedAlpha is: 2254.957137627416,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.2984985184063114,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 30.881063339830064
# --------------------------
# galaxyName is: NGC5005_rotmod
# chiSquare is: 0.10709803416378519
# fittedAlpha is: -543.182269277443,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.2458708739017659,
# bulge_scale is: 0.6355439598445611
# avgChiSquared / len(lcmGalaxies) is: 30.888713199413193
# --------------------------
# galaxyName is: UGC10310_rotmod
# chiSquare is: 0.06042486120670369
# fittedAlpha is: 590.5377386955789,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.373817244261732,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 30.893029260927957
# --------------------------
# galaxyName is: NGC0300_rotmod
# chiSquare is: 0.46337996088755334
# fittedAlpha is: 1748.5195018462741,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.4197581663691319,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 30.92612782956278
# --------------------------
# galaxyName is: UGC06446_rotmod
# chiSquare is: 0.1988591063958701
# fittedAlpha is: 1090.6983873024685,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.050340859899339,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 30.9403320514482
# --------------------------
# galaxyName is: NGC5985_rotmod
# chiSquare is: 4.345714856800779
# fittedAlpha is: 256.4036385649837,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.0476846755025968,
# bulge_scale is: 4.216342324125982
# avgChiSquared / len(lcmGalaxies) is: 31.2507402555054
# --------------------------
# galaxyName is: DDO064_rotmod
# chiSquare is: 0.3849286238405146
# fittedAlpha is: 6856.153612495651,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.4256184800817553,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 31.27823515720829
# --------------------------
# galaxyName is: DDO170_rotmod
# chiSquare is: 2.327702042995028
# fittedAlpha is: 1874.2139234356302,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.713819213956601,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 31.444499588850793
# --------------------------
# galaxyName is: UGC09037_rotmod
# chiSquare is: 1.6894599335234601
# fittedAlpha is: 1140.0128497057237,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.3386837894067576,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 31.56517529838818
# --------------------------
# galaxyName is: UGC11914_rotmod
# chiSquare is: 0.6702995708033219
# fittedAlpha is: 301.1601149364551,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.13957553723081303,
# bulge_scale is: 0.8864295097974418
# avgChiSquared / len(lcmGalaxies) is: 31.613053839159846
# --------------------------
# galaxyName is: NGC0289_rotmod
# chiSquare is: 1.686886793906819
# fittedAlpha is: 125.92651830975967,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.7143605401713632,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 31.733545753010333
# --------------------------
# galaxyName is: UGC06923_rotmod
# chiSquare is: 0.4719428113514345
# fittedAlpha is: 3254.734370549919,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.6298294101996758,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 31.76725595382115
# --------------------------
# galaxyName is: NGC7793_rotmod
# chiSquare is: 0.8544512894833467
# fittedAlpha is: 409.9582365727994,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.8233165257471898,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 31.828288188784246
# --------------------------
# galaxyName is: NGC4214_rotmod
# chiSquare is: 0.6953418150827401
# fittedAlpha is: 619.5433330817888,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.2747111867882646,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 31.877955461290153
# --------------------------
# galaxyName is: UGC05764_rotmod
# chiSquare is: 6.8118265749571325
# fittedAlpha is: 1165.760718462353,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 13.77618633250183,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 32.36451450235852
# --------------------------
# galaxyName is: UGC04278_rotmod
# chiSquare is: 1.0867528294964095
# fittedAlpha is: 14026.760739772702,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.91763164161744,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 32.442139704465404
# --------------------------
# galaxyName is: UGC05829_rotmod
# chiSquare is: 0.0606111008842299
# fittedAlpha is: 3950.93230715276,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.229622382855046,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 32.446469068814274
# --------------------------
# galaxyName is: UGC08837_rotmod
# chiSquare is: 0.3548755093238681
# fittedAlpha is: 31499.60946888191,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.4703646416446133,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 32.471817319480266
# --------------------------
# galaxyName is: UGC04325_rotmod
# chiSquare is: 2.1755712063815538
# fittedAlpha is: -130.6446234062426,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.6561793402811786,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 32.627215262793236
# --------------------------
# galaxyName is: NGC3521_rotmod
# chiSquare is: 0.2855255846164761
# fittedAlpha is: 144.4813846470602,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5275102331122493,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 32.6476099474087
# --------------------------
# galaxyName is: UGC07866_rotmod
# chiSquare is: 0.035208439761362856
# fittedAlpha is: 4573.857604551278,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.571597589464757,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 32.650124835963084
# --------------------------
# galaxyName is: UGC08286_rotmod
# chiSquare is: 1.4284522767057826
# fittedAlpha is: 863.8838483159285,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.949504461597826,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 32.75215714144207
# --------------------------
# galaxyName is: NGC4010_rotmod
# chiSquare is: 1.714078696344503
# fittedAlpha is: 1457.933981428873,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.7392243197034722,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 32.87459133403811
# --------------------------
# galaxyName is: NGC2683_rotmod
# chiSquare is: 1.2851875566167053
# fittedAlpha is: 93.08310645754058,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.9441465401981114,
# bulge_scale is: -0.6842883913597143
# avgChiSquared / len(lcmGalaxies) is: 32.96639044522501
# --------------------------
# galaxyName is: UGC07261_rotmod
# chiSquare is: 0.7184888392359875
# fittedAlpha is: 1009.2494978427131,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.5458258021306899,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 33.017711076599014
# --------------------------
# galaxyName is: UGC07608_rotmod
# chiSquare is: 0.1577658129489808
# fittedAlpha is: 10738.90574953748,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.5458863868850012,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 33.02898006323822
# --------------------------
# galaxyName is: IC2574_rotmod
# chiSquare is: 1.2978368609464734
# fittedAlpha is: 18546.65744821202,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.0653077932260309,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 33.12168269616297
# --------------------------
# galaxyName is: UGCA444_rotmod
# chiSquare is: 0.07626804901033128
# fittedAlpha is: 6539.0262558648565,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 13.484528337894796,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 33.12713041394942
# --------------------------
# galaxyName is: UGC00891_rotmod
# chiSquare is: 1.9948731696045037
# fittedAlpha is: 6231.485280370627,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.2129686263575437,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 33.269621354635454
# --------------------------
# galaxyName is: UGC06983_rotmod
# chiSquare is: 0.8387968226190484
# fittedAlpha is: 852.4289815161004,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.673857949656665,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 33.32953541339396
# --------------------------
# galaxyName is: UGC05986_rotmod
# chiSquare is: 3.0122361634661656
# fittedAlpha is: 1157.522964412473,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.4483048488852182,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 33.54469513935583
# --------------------------
# galaxyName is: UGC06930_rotmod
# chiSquare is: 0.34790003373327244
# fittedAlpha is: 490.9975674471033,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.6143110523198076,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 33.569545141765346
# --------------------------
# galaxyName is: ESO116-G012_rotmod
# chiSquare is: 1.5701972905190247
# fittedAlpha is: 1567.2981952256323,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.1549607689305892,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 33.681702091088134
# --------------------------
# galaxyName is: NGC5585_rotmod
# chiSquare is: 6.317378774926016
# fittedAlpha is: 2902.963774131252,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5821689794830506,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 34.13294343215428
# --------------------------
# galaxyName is: NGC6674_rotmod
# chiSquare is: 1.4567588265039866
# fittedAlpha is: 146.91723059332452,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.8909462684618467,
# bulge_scale is: 2.2436116307473766
# avgChiSquared / len(lcmGalaxies) is: 34.23699763404742
# --------------------------
# galaxyName is: NGC3109_rotmod
# chiSquare is: 0.3165824175043709
# fittedAlpha is: 11640.46047447032,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 4.0344708540774175,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 34.25961066386916
# --------------------------
# galaxyName is: F571-8_rotmod
# chiSquare is: 0.5455529461949238
# fittedAlpha is: 9012.192866579422,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.13247296079371157,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 34.29857873145451
# --------------------------
# galaxyName is: DDO154_rotmod
# chiSquare is: 16.22006021034118
# fittedAlpha is: 12222.279455958746,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.7079192255441222,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 35.45715446076459
# --------------------------
# galaxyName is: NGC4051_rotmod
# chiSquare is: 0.9503629015817133
# fittedAlpha is: 148.67356048666284,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.6111922082384945,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 35.52503752516329
# --------------------------
# galaxyName is: UGC11455_rotmod
# chiSquare is: 3.5740305464176227
# fittedAlpha is: 304.53662964755836,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5844671395533233,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 35.78032542133598
# --------------------------
# galaxyName is: UGC06628_rotmod
# chiSquare is: 0.03419726403151367
# fittedAlpha is: -1556.6648077597595,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.0874404581606398,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 35.78276808305252
# --------------------------
# galaxyName is: F579-V1_rotmod
# chiSquare is: 0.738716923969413
# fittedAlpha is: -135.18014622471128,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.932050453082509,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 35.83553357762176
# --------------------------
# galaxyName is: UGC08699_rotmod
# chiSquare is: 0.5813185375704225
# fittedAlpha is: 82.51535903816695,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.8112655769577298,
# bulge_scale is: 0.6055721055598337
# avgChiSquared / len(lcmGalaxies) is: 35.877056330305365
# --------------------------
# galaxyName is: NGC4085_rotmod
# chiSquare is: 1.76887896536833
# fittedAlpha is: 1924.6887775799535,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.3360681403787029,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 36.00340482783167
# --------------------------
# galaxyName is: UGC07089_rotmod
# chiSquare is: 0.10400732633459397
# fittedAlpha is: 3319.536733400681,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.8874809104210507,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 36.01083392256986
# --------------------------
# galaxyName is: KK98-251_rotmod
# chiSquare is: 0.3579598856985953
# fittedAlpha is: 8163.220773020877,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 2.6784311342172353,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 36.036402485834046
# --------------------------
# galaxyName is: UGC02455_rotmod
# chiSquare is: 0.6911873916437568
# fittedAlpha is: 16442.1543230826,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.06937180434677304,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 36.0857730138086
# --------------------------
# galaxyName is: UGCA281_rotmod
# chiSquare is: 0.17461817167194368
# fittedAlpha is: 4482.56780773742,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.5399581042590185,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 36.098245740356596
# --------------------------
# galaxyName is: CamB_rotmod
# chiSquare is: 0.007028746010011573
# fittedAlpha is: 129680.17036637515,
# fittedVLumFreeParam is: 1.0
# disk_scale is: -0.002029425350640134,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 36.09874779364303
# --------------------------
# galaxyName is: NGC3949_rotmod
# chiSquare is: 0.323428130043178
# fittedAlpha is: 451.8874718919909,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5334877964884628,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 36.12184980293183
# --------------------------
# galaxyName is: NGC7814_rotmod
# chiSquare is: 0.46734975584588856
# fittedAlpha is: 114.30063286393892,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.3061661654640881,
# bulge_scale is: 0.4784920871854589
# avgChiSquared / len(lcmGalaxies) is: 36.15523192834939
# --------------------------
# galaxyName is: UGC02916_rotmod
# chiSquare is: 10.405617117788413
# fittedAlpha is: 66.71418653913845,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.75821175315834,
# bulge_scale is: 0.4967977615733083
# avgChiSquared / len(lcmGalaxies) is: 36.8984902939057
# --------------------------
# galaxyName is: N2841_TaM_original
# chiSquare is: 0.6365190033362451
# fittedAlpha is: 245.68203524413502,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.0992685977882375,
# bulge_scale is: 1.111682044932795
# avgChiSquared / len(lcmGalaxies) is: 36.94395593700115
# --------------------------
# galaxyName is: UGC01281_rotmod
# chiSquare is: 0.3898988491429243
# fittedAlpha is: 9694.445794839821,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.9900978820148327,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 36.971805854797076
# --------------------------
# galaxyName is: NGC2903_rotmod
# chiSquare is: 18.65470430028354
# fittedAlpha is: 116.55282797306938,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.5191422717644019,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 38.30428473338876
# --------------------------
# galaxyName is: NGC4088_rotmod
# chiSquare is: 0.39356783411513313
# fittedAlpha is: 266.67416975162786,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 0.42178177697172875,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 38.332396721539844
# --------------------------
# galaxyName is: UGC05414_rotmod
# chiSquare is: 0.09267387806727945
# fittedAlpha is: 5015.920761006494,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.0908109361409437,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 38.33901628425894
# --------------------------
# galaxyName is: UGC06787_rotmod
# chiSquare is: 109.6058670570297
# fittedAlpha is: -624.0902745764761,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 3.5048605993705984,
# bulge_scale is: 0.6938500877213233
# avgChiSquared / len(lcmGalaxies) is: 46.16800678833249
# --------------------------
# galaxyName is: UGC07690_rotmod
# chiSquare is: 0.3571109522592205
# fittedAlpha is: 541.2985985773929,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.1769714919740084,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 46.19351471349386
# --------------------------
# galaxyName is: NGC2366_rotmod
# chiSquare is: 2.4709201715257163
# fittedAlpha is: 7008.705623405672,
# fittedVLumFreeParam is: 1.0
# disk_scale is: 1.1072162088735729,
# bulge_scale is: 1.0
# avgChiSquared / len(lcmGalaxies) is: 46.37000901145998
# --------------------------

# %%
# Out:
# array([1., 1., 1., 1.])
