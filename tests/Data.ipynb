# %%
import sys
sys.path.append('../')
from data import Data
d = Data()

# %%
d.getGalaxyFiles("../data/Rotmod_LTG")
# Out:
# ['NGC5371_rotmod.dat',
#  'UGC07603_rotmod.dat',
#  'NGC4138_rotmod.dat',
#  'UGC12632_rotmod.dat',
#  'NGC5033_rotmod.dat',
#  'UGC02023_rotmod.dat',
#  'UGC09133_rotmod.dat',
#  'UGCA442_rotmod.dat',
#  'UGC04305_rotmod.dat',
#  'NGC2841_rotmod.dat',
#  'NGC2955_rotmod.dat',
#  'UGC07232_rotmod.dat',
#  'NGC4157_rotmod.dat',
#  'NGC4183_rotmod.dat',
#  'UGC07125_rotmod.dat',
#  'UGC03205_rotmod.dat',
#  'F583-1_rotmod.dat',
#  'NGC4068_rotmod.dat',
#  'UGC02885_rotmod.dat',
#  'D564-8_rotmod.dat',
#  'NGC4013_rotmod.dat',
#  'UGC07323_rotmod.dat',
#  'NGC3953_rotmod.dat',
#  'NGC4559_rotmod.dat',
#  'NGC6015_rotmod.dat',
#  'UGC05253_rotmod.dat',
#  'UGC12506_rotmod.dat',
#  'NGC2998_rotmod.dat',
#  'UGC00731_rotmod.dat',
#  'F583-4_rotmod.dat',
#  'UGC06614_rotmod.dat',
#  'NGC0024_rotmod.dat',
#  'DDO168_rotmod.dat',
#  'UGC05750_rotmod.dat',
#  'UGC05005_rotmod.dat',
#  'NGC3893_rotmod.dat',
#  'UGC12732_rotmod.dat',
#  'UGC06818_rotmod.dat',
#  'IC4202_rotmod.dat',
# ...

# %%
galaxies = d.getGalaxyData("../data/Rotmod_LTG/")

# %%
print(galaxies["NGC5371_rotmod.dat"][0])
# Out:
# [1.45, 216.0, 10.0, 0.0, 240.9, 0.0, 1579.45, 0.0]
